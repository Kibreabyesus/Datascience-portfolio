# %% [markdown]
# # Working with Pandas DataFrames

# %% [markdown]
# ## 1. Getting Started
# We first import `pandas`.

# %%
import ... as pd

# %% [markdown]
# - Read the file large_countries_2015.csv into a countries df.
#
# - Set the country names as the index.

# %%
countries = ...('large_countries_2015.csv', 
                        ...)

# %% [markdown]
# Print the type of a single column in pandas.

# %%
print("population column is of type:", ...(countries["population"]))
# Out:
# population column is of type: <class 'pandas.core.series.Series'>

# %% [markdown]
# - Print data types of each column.

# %%
print(f"""{countries...}""")

# %% [markdown]
# - To view the contents of a data frame, type its name:

# %%
...
# Out:
#                  population  fertility      continent
# Bangladesh     1.609956e+08       2.12           Asia
# Brazil         2.078475e+08       1.78  South America
# China          1.376049e+09       1.57           Asia
# India          1.311051e+09       2.43           Asia
# Indonesia      2.575638e+08       2.28           Asia
# Japan          1.265735e+08       1.45           Asia
# Mexico         1.270172e+08       2.13  North America
# Nigeria        1.822020e+08       5.89         Africa
# Pakistan       1.889249e+08       3.04           Asia
# Philippines    1.006994e+08       2.98           Asia
# Russia         1.434569e+08       1.61         Europe
# United States  3.217736e+08       1.97  North America

# %% [markdown]
# - Check out the documentation for pandas DataFrame. You can use shift + tab for this after replacing your cursor on the object.

# %%
...

# %% [markdown]
# Or you can check it here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# - Show the index (row) labels of the countries dataframe.

# %%
countries...
# Out:
# Index(['Bangladesh', 'Brazil', 'China', 'India', 'Indonesia', 'Japan',
#        'Mexico', 'Nigeria', 'Pakistan', 'Philippines', 'Russia',
#        'United States'],
#       dtype='object')

# %% [markdown]
# - Show the column names.

# %%
countries...
# Out:
# Index(['population', 'fertility', 'continent'], dtype='object')

# %% [markdown]
# - Move the command below, above this cell with arrows.

# %%
countries.info()
